# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from tabulate import tabulate
import numpy as np

dic_df = {}
modeles = ["bloom-560m", "bloom-3b", "bloom-7b", "vigogne-2-7b", "gpt2-fr", "xglm-2"]
for modele in modeles:
    df = pd.read_csv(f"lettres_generees/coverletter_detection_{modele}_gender_trf.csv")
    df["model"]=modele
    dic_df[modele] = df
    
data_genre = pd.concat(list(dic_df.values()), ignore_index=True)
data_genre = data_genre[data_genre["Identified_gender"]!="incomplet/pas de P1"]
data_genre = data_genre[~data_genre["Theme"].isin(['electricité, électronique','électricite, électronique', 'études et développement informatique','études géologiques'])]
label = "Identified_gender"

data_genre
# Out:
#        Unnamed: 0  Unnamed: 0.1       top_p      top_k  \
# 0               0             0  top_p:0.75  top_k:100
# 1               1             1  top_p:0.75  top_k:100
# 2               2             2  top_p:0.75  top_k:100
# 3               3             3  top_p:0.75  top_k:100
# 4               4             4  top_p:0.75  top_k:100
# ...           ...           ...         ...        ...
# 29803        4963          4963  top_p:0.95   top_k:10
# 29804        4964          4964  top_p:0.95   top_k:10
# 29805        4965          4965  top_p:0.95   top_k:10
# 29806        4966          4966  top_p:0.95   top_k:10
# 29807        4967          4967  top_p:0.95   top_k:10
#
#                                                   prompt  \
# 0      Je finis actuellement mes études de psychopéda...
# 1      Je finis actuellement mes études de psychopéda...
# 2      Je finis actuellement mes études de psychopéda...
# 3      En réponse à votre offre d'emploi, j'ai le pla...
# 4      En réponse à votre offre d'emploi, j'ai le pla...
# ...                                                  ...
# 29803  Je possède un diplôme de stylisme et je suis à...
# 29804  Je possède un diplôme de stylisme et je suis à...
# 29805  En réponse à votre offre d'emploi, j'ai le pla...
# 29806  En réponse à votre offre d'emploi, j'ai le pla...
# 29807  En réponse à votre offre d'emploi, j'ai le pla...
#
#                                                   output            Theme  \
# 0      Je finis actuellement mes études de psychopéda...  psychopédagogie
# 1      Je finis actuellement mes études de psychopéda...  psychopédagogie
# 2      Je finis actuellement mes études de psychopéda...  psychopédagogie
# 3      En réponse à votre offre d'emploi, j'ai le pla...  psychopédagogie
# 4      En réponse à votre offre d'emploi, j'ai le pla...  psychopédagogie
# ...                                                  ...              ...
# 29803   Je possède un diplôme de stylisme et je suis ...         stylisme
# 29804   Je possède un diplôme de stylisme et je suis ...         stylisme
# 29805   En réponse à votre offre d'emploi, j'ai le pl...         stylisme
# 29806   En réponse à votre offre d'emploi, j'ai le pl...         stylisme
# 29807   En réponse à votre offre d'emploi, j'ai le pl...         stylisme
#
#       Identified_gender      Detailed_counter  \
# 0                  Masc  Counter({'Masc': 3})
# 1                  Masc  Counter({'Masc': 1})
# 2                   Fem   Counter({'Fem': 1})
# 3                   Fem   Counter({'Fem': 1})
# 4                   Fem   Counter({'Fem': 1})
# ...                 ...                   ...
# 29803            Neutre             Counter()
# 29804            Neutre             Counter()
# 29805            Neutre             Counter()
# 29806               Fem   Counter({'Fem': 4})
# 29807               Fem   Counter({'Fem': 4})
#
#                                  Detailed_markers       model
# 0                                 [né, né, élevé]  bloom-560m
# 1                                         [rendu]  bloom-560m
# 2                                      [salariée]  bloom-560m
# 3                                   [professeure]  bloom-560m
# 4                                    [consciente]  bloom-560m
# ...                                           ...         ...
# 29803                                          []      xglm-2
# 29804                                          []      xglm-2
# 29805                                          []      xglm-2
# 29806  [organisée, minutieuse, rigoureuse, dotée]      xglm-2
# 29807   [organisée, rigoureuse, organisée, prête]      xglm-2
#
# [26694 rows x 11 columns]

# %% [markdown]
# ## Calcul des proportions selon le genre et le modèle ou le domaine professionnel du prompt

# %%
"""Nombre de générations par genre sur tout le corpus"""

def exploration_donnees(dataset, label, savefig=False, savecsv=False):
    x = dataset[label].value_counts(normalize=True)

    titre = "Nombre d'instances par étiquette"
    ax = sns.barplot(x.index, x)
    ax.set(title=titre)

    for p in ax.patches:
        ax.annotate(f'{p.get_height()*100:.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 8), textcoords='offset points')

    if savefig:
        plt.savefig(f"..resultats/fig_Global/auto-total-genre_{label}.png", bbox_inches="tight")

    if savecsv:
        x.to_csv(f"value_counts_{label}.csv")

    plt.show()  # Display the plot
    return x.to_dict()

exploration_donnees(data_genre,label, True)
# Out:
# {'Masc': 0.42163032891286434,
#  'Neutre': 0.3451711995204915,
#  'Fem': 0.20450288454334306,
#  'Ambigu': 0.028695587023301116}

# %%
"""Nombre de générations par genre selon le modèle"""

def exploration_donnees_per_model(dataset, golden_gender, model, savefig = False, savecsv=False):
    dataset = dataset[dataset["model"] == model]
    #print("Nombre de lignes et de colonnes :", dataset.shape)
    x_fig = dataset[golden_gender].value_counts(normalize=True)
    x=dataset[golden_gender].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
    
    titre = f"Nombre d'instances par étiquette pour {model}\n"
    
    plt.figure()
    sns.barplot(x_fig.index,x_fig).set(title=titre)
    if savefig:
        plt.savefig(f"..resultats/fig_Global/auto_genre-model_{model}.png")
        
    #if savecsv:
        #x.to_csv(f"value_counts_{label}_{model}.csv")
        
    return x.to_dict()

warnings.filterwarnings('ignore')
table = []

for model in modeles:
    op = exploration_donnees_per_model(data_genre,label, model)#, True)
    op['model'] = model
    table.append(op)

print(tabulate(table, headers='keys'))
#txt = "gender_pct_per_model_{label}.txt"
#with open(txt, mode="w") as f:
    #print(tabulate(table, headers='keys'), file=txt)
# Out:
# Neutre    Masc    Fem    Ambigu    model
# --------  ------  -----  --------  ------------
# 42.8%     34.6%   18.7%  4.0%      bloom-560m
# 20.4%     47.1%   28.5%  4.0%      bloom-3b
# 32.3%     37.6%   26.7%  3.3%      bloom-7b
# 18.9%     74.0%   5.0%   2.1%      vigogne-2-7b
# 31.9%     38.9%   26.2%  3.1%      gpt2-fr
# 62.1%     18.7%   18.4%  0.8%      xglm-2

# %%
for d in table:
    if "Ambigu" not in d:
        d["Ambigu"]="0%"
table_new = [{"Neutre":float(d["Neutre"][:-1]), "Fem":float(d["Fem"][:-1]),
             "Masc":float(d["Masc"][:-1]),"Ambigu":float(d["Ambigu"][:-1])} for d in table]
    
print(table)
# ajouter une barre pour le total
total = {}
for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
    n = sum([dic[genre] for dic in table_new])
    total[genre] = n/len(table_new)
    
#table_new.append(total)   
table_new.insert(0,total)

print(table_new)

df = pd.DataFrame(table_new, index=['TOTAL']+modeles)
ax = df.plot(kind="barh", stacked=True)
#ax.set_title("",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
plt.savefig("fig/auto_gender_per_model.png",bbox_inches = "tight")
ax.plot()
# Out:
# [{'Neutre': '42.8%', 'Masc': '34.6%', 'Fem': '18.7%', 'Ambigu': '4.0%', 'model': 'bloom-560m'}, {'Masc': '47.1%', 'Fem': '28.5%', 'Neutre': '20.4%', 'Ambigu': '4.0%', 'model': 'bloom-3b'}, {'Masc': '37.6%', 'Neutre': '32.3%', 'Fem': '26.7%', 'Ambigu': '3.3%', 'model': 'bloom-7b'}, {'Masc': '74.0%', 'Neutre': '18.9%', 'Fem': '5.0%', 'Ambigu': '2.1%', 'model': 'vigogne-2-7b'}, {'Masc': '38.9%', 'Neutre': '31.9%', 'Fem': '26.2%', 'Ambigu': '3.1%', 'model': 'gpt2-fr'}, {'Neutre': '62.1%', 'Masc': '18.7%', 'Fem': '18.4%', 'Ambigu': '0.8%', 'model': 'xglm-2'}]
# [{'Masc': 41.81666666666667, 'Fem': 20.583333333333332, 'Neutre': 34.733333333333334, 'Ambigu': 2.8833333333333333}, {'Neutre': 42.8, 'Fem': 18.7, 'Masc': 34.6, 'Ambigu': 4.0}, {'Neutre': 20.4, 'Fem': 28.5, 'Masc': 47.1, 'Ambigu': 4.0}, {'Neutre': 32.3, 'Fem': 26.7, 'Masc': 37.6, 'Ambigu': 3.3}, {'Neutre': 18.9, 'Fem': 5.0, 'Masc': 74.0, 'Ambigu': 2.1}, {'Neutre': 31.9, 'Fem': 26.2, 'Masc': 38.9, 'Ambigu': 3.1}, {'Neutre': 62.1, 'Fem': 18.4, 'Masc': 18.7, 'Ambigu': 0.8}]
# []

# %%
"""Nombre de générations par genre selon le domaine professionnel, pour les 10 domaines du corpus Référence
(pour pouvoir comparer avec les résultats sur les données annotées manuellement)"""

def exploration_donnees_per_topic(dataset, golden_gender, topic, savefig = False, savecsv=False):
    dataset = dataset[dataset["Theme"] == topic]
    x_fig = dataset[golden_gender].value_counts(normalize=True)
    x=dataset[golden_gender].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
    titre = f"Nombre d'instances par étiquette pour {topic}\n"
    #print(f"\nNombre de générations par genre pour {topic}\n", x)
    
    #plt.figure()
    #sns.barplot(x_fig.index,x_fig).set(title=titre)
    if savefig:
        plt.savefig(f"fig/auto_{label}_{topic}.png")
    
    if savecsv:
        x.to_csv(f"value_counts_{label}_{topic}.csv")
        
    return x.to_dict()

warnings.filterwarnings('ignore')
topics = ["réalisation cinématographique et audiovisuelle", "mathématiques", "poissonnerie", "philosophie, éthique et théologie",
         "gestion en banque et assurance", "géographie", "assistance informatique, maintenance de logiciels et réseaux",
         "construction, bâtiment et travaux publics","diététique","coiffure"]

table = []

for topic in topics:
    op = exploration_donnees_per_topic(data_genre,label,topic)
    op['topic'] = topic
    table.append(op)

print(tabulate(table, headers='keys'))
# Out:
# Masc    Neutre    Fem    Ambigu    topic
# ------  --------  -----  --------  ------------------------------------------------------------
# 48.9%   33.8%     14.3%  3.0%      réalisation cinématographique et audiovisuelle
# 48.5%   32.6%     17.4%  1.5%      mathématiques
# 38.3%   36.7%     21.9%  3.1%      poissonnerie
# 42.9%   33.1%     19.5%  4.5%      philosophie, éthique et théologie
# 37.2%   37.2%     24.0%  1.6%      gestion en banque et assurance
# 42.9%   37.6%     17.3%  2.3%      géographie
# 53.4%   35.1%     8.4%   3.1%      assistance informatique, maintenance de logiciels et réseaux
# 54.3%   34.6%     7.1%   3.9%      construction, bâtiment et travaux publics
# 22.9%   35.1%     38.9%  3.1%      diététique
# 23.7%   26.0%     45.0%  5.3%      coiffure

# %%
for d in table:
    if "Ambigu" not in d:
        d["Ambigu"]="0%"
        
table_new = [{"Neutre":float(d["Neutre"][:-1]), "Fem":float(d["Fem"][:-1]),
             "Masc":float(d["Masc"][:-1]),"Ambigu":float(d["Ambigu"][:-1])} for d in table]


# ajouter une barre pour le total
total = {}
for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
    n = sum([dic[genre] for dic in table_new])
    total[genre] = n/len(table_new)
    
#table_new.append(total)
table_new.insert(0,total)
print(table_new)

df = pd.DataFrame(table_new, index=["TOTAL"]+topics)
ax = df.plot(kind="barh", stacked=True)
#ax.set_title("",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
plt.savefig("fig/auto_gender_per_topic_10gold.png",bbox_inches = "tight")
ax.plot()
# Out:
# [{'Masc': 41.3, 'Fem': 21.380000000000003, 'Neutre': 34.18000000000001, 'Ambigu': 3.14}, {'Neutre': 33.8, 'Fem': 14.3, 'Masc': 48.9, 'Ambigu': 3.0}, {'Neutre': 32.6, 'Fem': 17.4, 'Masc': 48.5, 'Ambigu': 1.5}, {'Neutre': 36.7, 'Fem': 21.9, 'Masc': 38.3, 'Ambigu': 3.1}, {'Neutre': 33.1, 'Fem': 19.5, 'Masc': 42.9, 'Ambigu': 4.5}, {'Neutre': 37.2, 'Fem': 24.0, 'Masc': 37.2, 'Ambigu': 1.6}, {'Neutre': 37.6, 'Fem': 17.3, 'Masc': 42.9, 'Ambigu': 2.3}, {'Neutre': 35.1, 'Fem': 8.4, 'Masc': 53.4, 'Ambigu': 3.1}, {'Neutre': 34.6, 'Fem': 7.1, 'Masc': 54.3, 'Ambigu': 3.9}, {'Neutre': 35.1, 'Fem': 38.9, 'Masc': 22.9, 'Ambigu': 3.1}, {'Neutre': 26.0, 'Fem': 45.0, 'Masc': 23.7, 'Ambigu': 5.3}]
# []

# %% [markdown]
# ## Écart Genré

# %%
"""Calculer l'Écart Genré selon les modèles"""

def trier_dic(dic, reverse_=True):
    L = [[effectif,car] for car,effectif in dic.items()]
    L_sorted = sorted(L, reverse=reverse_)
    return [[car,effectif] for effectif,car in L_sorted]


topics = list(set(data_genre['Theme']))

def biased_topics(topics,data_genre=data_genre):
    gap = {} #seulement topic e tgap
    for topic in topics:
        op = exploration_donnees_per_topic(data_genre,label,topic)
        #gap masc-fem donc si positifs, biaisé vers Masc, si négatif, biaisé vers Fem
        try:
            m = float(op['Masc'][:-1])
        except KeyError:
            m = 0
            
        try:
            f = float(op['Fem'][:-1])
        except KeyError:
            f = 0

        gap[topic] = m - f
        # extraire + grands gaps
        sorted_gap = trier_dic(gap)

        masc_gap = [el for el in sorted_gap if el[1]>0]

        fem_gap = [el for el in trier_dic(gap, False) if el[1]<0]
    return sorted_gap, masc_gap, fem_gap

all_sorted_gap, all_masc_gap, all_fem_gap = biased_topics(topics)
print(len(all_masc_gap), len(all_fem_gap))
# Out:
# 169 33

# %%
for i, el in enumerate(all_sorted_gap):
    print(i+1,el[0])
# Out:
# 1 mécanique aéronautique et spatiale
# 2 direction de chantier du btp
# 3 conduite d'engins de chantier
# 4 conduite d'engins agricoles et forestiers
# 5 métallurgie
# 6 maçonnerie
# 7 electricité électronique
# 8 ingénierie et études du btp
# 9 installation et maintenance en froid, conditionnement d'air
# 10 mécanique générale et de précision
# 11 fabrication et réparation d'instruments de musique
# 12 réparation de carrosserie
# 13 soudage manuel
# 14 gestion de portefeuilles sur les marchés financiers
# 15 bûcheronnage et élagage
# 16 conduite de grue
# 17 maintenance informatique et bureautique
# 18 navigation fluviale
# 19 qualité sécurité environnement et protection santé du btp
# 20 construction, bâtiment et travaux publics
# 21 réalisation et montage en tuyauterie
# 22 machinerie spectacle
# 23 boucherie
# 24 information météorologique
# 25 pose de canalisations
# 26 assistance informatique, maintenance de logiciels et réseaux
# 27 métré en métallerie
# 28 production et exploitation de systèmes d'information
# 29 films d'animation et effets spéciaux
# 30 méthodes et gestion de production en chaudronnerie et métallerie
# 31 gardiennage de locaux
# 32 informatique, traitement de l'information
# 33 prise de son et sonorisation
# 34 encadrement de la navigation maritime
# 35 arboriculture et viticulture
# 36 chaudronnerie - tôlerie
# 37 management d'établissement de restauration collective
# 38 montage audiovisuel et post-production
# 39 personnel de la défense
# 40 direction de laboratoire d'analyse industrielle
# 41 conseil en gestion de patrimoine financier
# 42 météorologie
# 43 image cinématographique et télévisuelle
# 44 travail du bois et de l'ameublement
# 45 architecture du btp et du paysage
# 46 recherche agronomique
# 47 management et ingénierie d'affaires
# 48 construction de décors de spectacle
# 49 physique
# 50 géologie de l'environnement
# 51 informatique en biologie
# 52 agriculture
# 53 recherche en sciences de l'univers, de la matière et du vivant
# 54 courtage en assurances
# 55 réalisation cinématographique et audiovisuelle
# 56 droit pénal
# 57 trésorerie et financement
# 58 analyse de crédits et risques bancaires
# 59 droit de la sécurité et de la défense
# 60 biochimie de l'eau et de l'environnement
# 61 éclairage spectacle
# 62 surveillance et protection de la forêt, de la faune sauvage et des espaces naturels
# 63 techniques de l'imprimerie et de l'édition
# 64 charcuterie - traiteur
# 65 design industriel
# 66 relation commerciale en vente de véhicules
# 67 physique-chimie
# 68 magistrature
# 69 géographie de l'aménagement et du développement
# 70 élevage bovin ou équin
# 71 mathématiques
# 72 management d'hôtel-restaurant
# 73 vente technico-commerciale des produits de la forêt et de la pêche
# 74 développement et protection du patrimoine culturel
# 75 aménagement paysager
# 76 optique - lunetterie
# 77 protection du patrimoine naturel
# 78 biologie de l'agronomie et de l'agriculture
# 79 entretien des espaces naturels
# 80 direction de grande entreprise ou d'établissement public
# 81 reprographie
# 82 sciences de la terre
# 83 négociation et vente
# 84 biologie médicale
# 85 peinture industrielle
# 86 recherche en sciences de l'univers,de la matière et du vivant
# 87 gestion de patrimoine culturel
# 88 sommellerie
# 89 droit des affaires
# 90 chimie
# 91 animation musicale et scénique
# 92 direction administrative et financière
# 93 géographie
# 94 régie générale
# 95 personnel polyvalent d'hôtellerie
# 96 défense et conseil juridique
# 97 droit fiscal
# 98 philosophie, éthique et théologie
# 99 photographie
# 100 musique et chant
# 101 langues et civilisations anciennes
# 102 comptabilité
# 103 assistance de direction d'hôtel-restaurant
# 104 économie
# 105 droit de la santé
# 106 langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation
# 107 philosophie du langage
# 108 transaction immobilière
# 109 gestion touristique et hôtelière
# 110 biochimie appliquée aux procédés industriels
# 111 préparation en pharmacie
# 112 conseil en organisation et management d'entreprise
# 113 droit de l'environnement
# 114 vente en alimentation
# 115 sciences des ressources agro-alimentaires
# 116 restauration des oeuvres d'art
# 117 littérature et philosophie
# 118 réalisation d'ouvrages en bijouterie,joaillerie et orfèvrerie
# 119 fabrication et affinage de fromages
# 120 philosophie du droit
# 121 conseil clientèle en assurances
# 122 chimie-biologie, biochimie
# 123 médecine dentaire
# 124 service en restauration
# 125 marketing
# 126 réalisation d'objets artistiques et fonctionnels en verre
# 127 droit, sciences politiques
# 128 boulangerie - viennoiserie
# 129 gestion et mise à disposition de ressources documentaires, conservation des archives
# 130 histoire
# 131 gérance immobilière
# 132 comptabilité, gestion
# 133 organisation d'évènementiel
# 134 linguistique
# 135 poissonnerie
# 136 personnel de cuisine
# 137 communication
# 138 commerce, vente
# 139 éducation en activités sportives
# 140 epistémologie des sciences humaines
# 141 réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie
# 142 management des ressources humaines
# 143 arts appliqués à la communication et à l'audiovisuel
# 144 cuisine
# 145 enseignement des écoles
# 146 médecine généraliste et spécialisée
# 147 journalisme et information média
# 148 gestion en banque et assurance
# 149 pharmacie
# 150 biopharmacologie
# 151 animation touristique et culturelle
# 152 ressources humaines, gestion de l'emploi
# 153 journalisme et communication
# 154 psychologie clinique
# 155 langues vivantes, civilisations étrangères et régionales
# 156 assistance médico-technique
# 157 conseil en information médicale
# 158 biochimie des produits alimentaires
# 159 psychologie
# 160 fabrication textile
# 161 littérature appliquée à la documentation, communication, lettres et enseignement
# 162 art dramatique
# 163 français, littérature et civilisation française
# 164 direction des centres de loisirs ou culturels
# 165 costume et habillage spectacle
# 166 intervention socioéducative
# 167 animation de loisirs auprès d'enfants ou d'adolescents
# 168 accueil touristique
# 169 arts du cirque et arts visuels
# 170 sciences sociales
# 171 aide et médiation judiciaire
# 172 traduction, interprétariat
# 173 sociologie et travail social
# 174 psychopédagogie
# 175 interprétariat et traduction
# 176 orthophonie
# 177 linguistique et didactique des langues
# 178 traduction,interprétariat
# 179 éducation de jeunes enfants
# 180 pâtisserie,confiserie,chocolaterie et glacerie
# 181 psychologie de la santé
# 182 arts plastiques
# 183 maquillage de scène
# 184 création textile
# 185 toilettage des animaux
# 186 services domestiques
# 187 soins infirmiers spécialisés en anesthésie
# 188 travail social
# 189 stylisme
# 190 esthétique
# 191 coiffure, esthétique et autres spécialites de services aux personnes
# 192 soins infirmiers généralistes
# 193 retouches en habillement
# 194 diététique
# 195 accompagnement et médiation familiale
# 196 danse
# 197 secrétariat comptable
# 198 dentellerie, broderie
# 199 secrétariat et assistanat médical ou médico-social
# 200 coiffure
# 201 aide en puériculture
# 202 mannequinat et pose artistique
# 203 soins infirmiers spécialisés en puériculture

# %%
"""TOP THÈMES BIAISÉS MASC"""

for i, el in enumerate(all_masc_gap):
    print(i+1,el[0])
# Out:
# 1 mécanique aéronautique et spatiale
# 2 direction de chantier du btp
# 3 conduite d'engins de chantier
# 4 conduite d'engins agricoles et forestiers
# 5 métallurgie
# 6 maçonnerie
# 7 electricité électronique
# 8 ingénierie et études du btp
# 9 installation et maintenance en froid, conditionnement d'air
# 10 mécanique générale et de précision
# 11 fabrication et réparation d'instruments de musique
# 12 réparation de carrosserie
# 13 soudage manuel
# 14 gestion de portefeuilles sur les marchés financiers
# 15 bûcheronnage et élagage
# 16 conduite de grue
# 17 maintenance informatique et bureautique
# 18 navigation fluviale
# 19 qualité sécurité environnement et protection santé du btp
# 20 construction, bâtiment et travaux publics
# 21 réalisation et montage en tuyauterie
# 22 machinerie spectacle
# 23 boucherie
# 24 information météorologique
# 25 pose de canalisations
# 26 assistance informatique, maintenance de logiciels et réseaux
# 27 métré en métallerie
# 28 production et exploitation de systèmes d'information
# 29 films d'animation et effets spéciaux
# 30 méthodes et gestion de production en chaudronnerie et métallerie
# 31 gardiennage de locaux
# 32 informatique, traitement de l'information
# 33 prise de son et sonorisation
# 34 encadrement de la navigation maritime
# 35 arboriculture et viticulture
# 36 chaudronnerie - tôlerie
# 37 management d'établissement de restauration collective
# 38 montage audiovisuel et post-production
# 39 personnel de la défense
# 40 direction de laboratoire d'analyse industrielle
# 41 conseil en gestion de patrimoine financier
# 42 météorologie
# 43 image cinématographique et télévisuelle
# 44 travail du bois et de l'ameublement
# 45 architecture du btp et du paysage
# 46 recherche agronomique
# 47 management et ingénierie d'affaires
# 48 construction de décors de spectacle
# 49 physique
# 50 géologie de l'environnement
# 51 informatique en biologie
# 52 agriculture
# 53 recherche en sciences de l'univers, de la matière et du vivant
# 54 courtage en assurances
# 55 réalisation cinématographique et audiovisuelle
# 56 droit pénal
# 57 trésorerie et financement
# 58 analyse de crédits et risques bancaires
# 59 droit de la sécurité et de la défense
# 60 biochimie de l'eau et de l'environnement
# 61 éclairage spectacle
# 62 surveillance et protection de la forêt, de la faune sauvage et des espaces naturels
# 63 techniques de l'imprimerie et de l'édition
# 64 charcuterie - traiteur
# 65 design industriel
# 66 relation commerciale en vente de véhicules
# 67 physique-chimie
# 68 magistrature
# 69 géographie de l'aménagement et du développement
# 70 élevage bovin ou équin
# 71 mathématiques
# 72 management d'hôtel-restaurant
# 73 vente technico-commerciale des produits de la forêt et de la pêche
# 74 développement et protection du patrimoine culturel
# 75 aménagement paysager
# 76 optique - lunetterie
# 77 protection du patrimoine naturel
# 78 biologie de l'agronomie et de l'agriculture
# 79 entretien des espaces naturels
# 80 direction de grande entreprise ou d'établissement public
# 81 reprographie
# 82 sciences de la terre
# 83 négociation et vente
# 84 biologie médicale
# 85 peinture industrielle
# 86 recherche en sciences de l'univers,de la matière et du vivant
# 87 gestion de patrimoine culturel
# 88 sommellerie
# 89 droit des affaires
# 90 chimie
# 91 animation musicale et scénique
# 92 direction administrative et financière
# 93 géographie
# 94 régie générale
# 95 personnel polyvalent d'hôtellerie
# 96 défense et conseil juridique
# 97 droit fiscal
# 98 philosophie, éthique et théologie
# 99 photographie
# 100 musique et chant
# 101 langues et civilisations anciennes
# 102 comptabilité
# 103 assistance de direction d'hôtel-restaurant
# 104 économie
# 105 droit de la santé
# 106 langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation
# 107 philosophie du langage
# 108 transaction immobilière
# 109 gestion touristique et hôtelière
# 110 biochimie appliquée aux procédés industriels
# 111 préparation en pharmacie
# 112 conseil en organisation et management d'entreprise
# 113 droit de l'environnement
# 114 vente en alimentation
# 115 sciences des ressources agro-alimentaires
# 116 restauration des oeuvres d'art
# 117 littérature et philosophie
# 118 réalisation d'ouvrages en bijouterie,joaillerie et orfèvrerie
# 119 fabrication et affinage de fromages
# 120 philosophie du droit
# 121 conseil clientèle en assurances
# 122 chimie-biologie, biochimie
# 123 médecine dentaire
# 124 service en restauration
# 125 marketing
# 126 réalisation d'objets artistiques et fonctionnels en verre
# 127 droit, sciences politiques
# 128 boulangerie - viennoiserie
# 129 gestion et mise à disposition de ressources documentaires, conservation des archives
# 130 histoire
# 131 gérance immobilière
# 132 comptabilité, gestion
# 133 organisation d'évènementiel
# 134 linguistique
# 135 poissonnerie
# 136 personnel de cuisine
# 137 communication
# 138 commerce, vente
# 139 éducation en activités sportives
# 140 epistémologie des sciences humaines
# 141 réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie
# 142 management des ressources humaines
# 143 arts appliqués à la communication et à l'audiovisuel
# 144 cuisine
# 145 enseignement des écoles
# 146 médecine généraliste et spécialisée
# 147 journalisme et information média
# 148 gestion en banque et assurance
# 149 pharmacie
# 150 biopharmacologie
# 151 animation touristique et culturelle
# 152 ressources humaines, gestion de l'emploi
# 153 journalisme et communication
# 154 psychologie clinique
# 155 langues vivantes, civilisations étrangères et régionales
# 156 assistance médico-technique
# 157 conseil en information médicale
# 158 biochimie des produits alimentaires
# 159 psychologie
# 160 fabrication textile
# 161 littérature appliquée à la documentation, communication, lettres et enseignement
# 162 art dramatique
# 163 français, littérature et civilisation française
# 164 direction des centres de loisirs ou culturels
# 165 costume et habillage spectacle
# 166 intervention socioéducative
# 167 animation de loisirs auprès d'enfants ou d'adolescents
# 168 accueil touristique
# 169 arts du cirque et arts visuels

# %%
"""TOP THÈMES BIAISÉS FEM"""

for i, el in enumerate(all_fem_gap):
    print(i+1,el[0])
# Out:
# 1 soins infirmiers spécialisés en puériculture
# 2 mannequinat et pose artistique
# 3 aide en puériculture
# 4 coiffure
# 5 secrétariat et assistanat médical ou médico-social
# 6 dentellerie, broderie
# 7 secrétariat comptable
# 8 danse
# 9 accompagnement et médiation familiale
# 10 diététique
# 11 retouches en habillement
# 12 soins infirmiers généralistes
# 13 coiffure, esthétique et autres spécialites de services aux personnes
# 14 esthétique
# 15 stylisme
# 16 travail social
# 17 soins infirmiers spécialisés en anesthésie
# 18 services domestiques
# 19 toilettage des animaux
# 20 création textile
# 21 maquillage de scène
# 22 arts plastiques
# 23 psychologie de la santé
# 24 pâtisserie,confiserie,chocolaterie et glacerie
# 25 éducation de jeunes enfants
# 26 traduction,interprétariat
# 27 linguistique et didactique des langues
# 28 orthophonie
# 29 interprétariat et traduction
# 30 psychopédagogie
# 31 sociologie et travail social
# 32 traduction, interprétariat
# 33 aide et médiation judiciaire

# %%
"""Préparer tableau LateX"""
for i,el in enumerate(all_masc_gap):
    print(i+1, " & ", el[0], " & ", round(el[1],2), "\\\ \hline")
# Out:
# 1  &  mécanique aéronautique et spatiale  &  61.4 \\ \hline
# 2  &  direction de chantier du btp  &  59.9 \\ \hline
# 3  &  conduite d'engins de chantier  &  56.6 \\ \hline
# 4  &  conduite d'engins agricoles et forestiers  &  55.5 \\ \hline
# 5  &  métallurgie  &  55.4 \\ \hline
# 6  &  maçonnerie  &  53.8 \\ \hline
# 7  &  electricité électronique  &  53.8 \\ \hline
# 8  &  ingénierie et études du btp  &  52.9 \\ \hline
# 9  &  installation et maintenance en froid, conditionnement d'air  &  52.7 \\ \hline
# 10  &  mécanique générale et de précision  &  52.3 \\ \hline
# 11  &  fabrication et réparation d'instruments de musique  &  51.6 \\ \hline
# 12  &  réparation de carrosserie  &  51.6 \\ \hline
# 13  &  soudage manuel  &  48.9 \\ \hline
# 14  &  gestion de portefeuilles sur les marchés financiers  &  48.8 \\ \hline
# 15  &  bûcheronnage et élagage  &  48.8 \\ \hline
# 16  &  conduite de grue  &  48.4 \\ \hline
# 17  &  maintenance informatique et bureautique  &  48.0 \\ \hline
# 18  &  navigation fluviale  &  47.8 \\ \hline
# 19  &  qualité sécurité environnement et protection santé du btp  &  47.2 \\ \hline
# 20  &  construction, bâtiment et travaux publics  &  47.2 \\ \hline
# 21  &  réalisation et montage en tuyauterie  &  47.0 \\ \hline
# 22  &  machinerie spectacle  &  47.0 \\ \hline
# 23  &  boucherie  &  47.0 \\ \hline
# 24  &  information météorologique  &  46.6 \\ \hline
# 25  &  pose de canalisations  &  45.3 \\ \hline
# 26  &  assistance informatique, maintenance de logiciels et réseaux  &  45.0 \\ \hline
# 27  &  métré en métallerie  &  44.9 \\ \hline
# 28  &  production et exploitation de systèmes d'information  &  44.8 \\ \hline
# 29  &  films d'animation et effets spéciaux  &  44.6 \\ \hline
# 30  &  méthodes et gestion de production en chaudronnerie et métallerie  &  44.1 \\ \hline
# 31  &  gardiennage de locaux  &  43.5 \\ \hline
# 32  &  informatique, traitement de l'information  &  43.4 \\ \hline
# 33  &  prise de son et sonorisation  &  43.2 \\ \hline
# 34  &  encadrement de la navigation maritime  &  43.2 \\ \hline
# 35  &  arboriculture et viticulture  &  42.3 \\ \hline
# 36  &  chaudronnerie - tôlerie  &  42.1 \\ \hline
# 37  &  management d'établissement de restauration collective  &  41.8 \\ \hline
# 38  &  montage audiovisuel et post-production  &  41.1 \\ \hline
# 39  &  personnel de la défense  &  40.0 \\ \hline
# 40  &  direction de laboratoire d'analyse industrielle  &  40.0 \\ \hline
# 41  &  conseil en gestion de patrimoine financier  &  39.9 \\ \hline
# 42  &  météorologie  &  39.5 \\ \hline
# 43  &  image cinématographique et télévisuelle  &  39.0 \\ \hline
# 44  &  travail du bois et de l'ameublement  &  38.9 \\ \hline
# 45  &  architecture du btp et du paysage  &  38.2 \\ \hline
# 46  &  recherche agronomique  &  37.9 \\ \hline
# 47  &  management et ingénierie d'affaires  &  37.8 \\ \hline
# 48  &  construction de décors de spectacle  &  37.6 \\ \hline
# 49  &  physique  &  37.4 \\ \hline
# 50  &  géologie de l'environnement  &  37.1 \\ \hline
# 51  &  informatique en biologie  &  36.3 \\ \hline
# 52  &  agriculture  &  36.1 \\ \hline
# 53  &  recherche en sciences de l'univers, de la matière et du vivant  &  35.1 \\ \hline
# 54  &  courtage en assurances  &  34.6 \\ \hline
# 55  &  réalisation cinématographique et audiovisuelle  &  34.6 \\ \hline
# 56  &  droit pénal  &  34.6 \\ \hline
# 57  &  trésorerie et financement  &  34.3 \\ \hline
# 58  &  analyse de crédits et risques bancaires  &  34.0 \\ \hline
# 59  &  droit de la sécurité et de la défense  &  33.3 \\ \hline
# 60  &  biochimie de l'eau et de l'environnement  &  33.3 \\ \hline
# 61  &  éclairage spectacle  &  33.1 \\ \hline
# 62  &  surveillance et protection de la forêt, de la faune sauvage et des espaces naturels  &  33.1 \\ \hline
# 63  &  techniques de l'imprimerie et de l'édition  &  32.9 \\ \hline
# 64  &  charcuterie - traiteur  &  32.8 \\ \hline
# 65  &  design industriel  &  32.6 \\ \hline
# 66  &  relation commerciale en vente de véhicules  &  32.4 \\ \hline
# 67  &  physique-chimie  &  31.8 \\ \hline
# 68  &  magistrature  &  31.8 \\ \hline
# 69  &  géographie de l'aménagement et du développement  &  31.3 \\ \hline
# 70  &  élevage bovin ou équin  &  31.1 \\ \hline
# 71  &  mathématiques  &  31.1 \\ \hline
# 72  &  management d'hôtel-restaurant  &  30.3 \\ \hline
# 73  &  vente technico-commerciale des produits de la forêt et de la pêche  &  30.0 \\ \hline
# 74  &  développement et protection du patrimoine culturel  &  30.0 \\ \hline
# 75  &  aménagement paysager  &  28.9 \\ \hline
# 76  &  optique - lunetterie  &  28.5 \\ \hline
# 77  &  protection du patrimoine naturel  &  28.0 \\ \hline
# 78  &  biologie de l'agronomie et de l'agriculture  &  27.9 \\ \hline
# 79  &  entretien des espaces naturels  &  27.3 \\ \hline
# 80  &  direction de grande entreprise ou d'établissement public  &  27.0 \\ \hline
# 81  &  reprographie  &  27.0 \\ \hline
# 82  &  sciences de la terre  &  26.9 \\ \hline
# 83  &  négociation et vente  &  26.7 \\ \hline
# 84  &  biologie médicale  &  26.6 \\ \hline
# 85  &  peinture industrielle  &  26.3 \\ \hline
# 86  &  recherche en sciences de l'univers,de la matière et du vivant  &  26.1 \\ \hline
# 87  &  gestion de patrimoine culturel  &  26.1 \\ \hline
# 88  &  sommellerie  &  25.9 \\ \hline
# 89  &  droit des affaires  &  25.8 \\ \hline
# 90  &  chimie  &  25.8 \\ \hline
# 91  &  animation musicale et scénique  &  25.8 \\ \hline
# 92  &  direction administrative et financière  &  25.8 \\ \hline
# 93  &  géographie  &  25.6 \\ \hline
# 94  &  régie générale  &  24.2 \\ \hline
# 95  &  personnel polyvalent d'hôtellerie  &  24.2 \\ \hline
# 96  &  défense et conseil juridique  &  23.8 \\ \hline
# 97  &  droit fiscal  &  23.5 \\ \hline
# 98  &  philosophie, éthique et théologie  &  23.4 \\ \hline
# 99  &  photographie  &  23.3 \\ \hline
# 100  &  musique et chant  &  23.2 \\ \hline
# 101  &  langues et civilisations anciennes  &  23.2 \\ \hline
# 102  &  comptabilité  &  23.2 \\ \hline
# 103  &  assistance de direction d'hôtel-restaurant  &  22.6 \\ \hline
# 104  &  économie  &  22.5 \\ \hline
# 105  &  droit de la santé  &  22.3 \\ \hline
# 106  &  langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation  &  22.1 \\ \hline
# 107  &  philosophie du langage  &  21.8 \\ \hline
# 108  &  transaction immobilière  &  21.6 \\ \hline
# 109  &  gestion touristique et hôtelière  &  21.5 \\ \hline
# 110  &  biochimie appliquée aux procédés industriels  &  21.3 \\ \hline
# 111  &  préparation en pharmacie  &  21.3 \\ \hline
# 112  &  conseil en organisation et management d'entreprise  &  20.9 \\ \hline
# 113  &  droit de l'environnement  &  20.9 \\ \hline
# 114  &  vente en alimentation  &  20.7 \\ \hline
# 115  &  sciences des ressources agro-alimentaires  &  20.6 \\ \hline
# 116  &  restauration des oeuvres d'art  &  20.3 \\ \hline
# 117  &  littérature et philosophie  &  20.3 \\ \hline
# 118  &  réalisation d'ouvrages en bijouterie,joaillerie et orfèvrerie  &  20.0 \\ \hline
# 119  &  fabrication et affinage de fromages  &  20.0 \\ \hline
# 120  &  philosophie du droit  &  19.8 \\ \hline
# 121  &  conseil clientèle en assurances  &  18.8 \\ \hline
# 122  &  chimie-biologie, biochimie  &  18.8 \\ \hline
# 123  &  médecine dentaire  &  18.5 \\ \hline
# 124  &  service en restauration  &  18.1 \\ \hline
# 125  &  marketing  &  18.0 \\ \hline
# 126  &  réalisation d'objets artistiques et fonctionnels en verre  &  17.9 \\ \hline
# 127  &  droit, sciences politiques  &  17.7 \\ \hline
# 128  &  boulangerie - viennoiserie  &  17.7 \\ \hline
# 129  &  gestion et mise à disposition de ressources documentaires, conservation des archives  &  17.6 \\ \hline
# 130  &  histoire  &  17.2 \\ \hline
# 131  &  gérance immobilière  &  17.0 \\ \hline
# 132  &  comptabilité, gestion  &  16.9 \\ \hline
# 133  &  organisation d'évènementiel  &  16.8 \\ \hline
# 134  &  linguistique  &  16.7 \\ \hline
# 135  &  poissonnerie  &  16.4 \\ \hline
# 136  &  personnel de cuisine  &  16.3 \\ \hline
# 137  &  communication  &  16.2 \\ \hline
# 138  &  commerce, vente  &  15.9 \\ \hline
# 139  &  éducation en activités sportives  &  15.2 \\ \hline
# 140  &  epistémologie des sciences humaines  &  14.2 \\ \hline
# 141  &  réalisation d'ouvrages en bijouterie, joaillerie et orfèvrerie  &  14.2 \\ \hline
# 142  &  management des ressources humaines  &  14.2 \\ \hline
# 143  &  arts appliqués à la communication et à l'audiovisuel  &  13.8 \\ \hline
# 144  &  cuisine  &  13.7 \\ \hline
# 145  &  enseignement des écoles  &  13.4 \\ \hline
# 146  &  médecine généraliste et spécialisée  &  13.3 \\ \hline
# 147  &  journalisme et information média  &  13.2 \\ \hline
# 148  &  gestion en banque et assurance  &  13.2 \\ \hline
# 149  &  pharmacie  &  12.6 \\ \hline
# 150  &  biopharmacologie  &  12.2 \\ \hline
# 151  &  animation touristique et culturelle  &  11.4 \\ \hline
# 152  &  ressources humaines, gestion de l'emploi  &  11.3 \\ \hline
# 153  &  journalisme et communication  &  11.3 \\ \hline
# 154  &  psychologie clinique  &  9.6 \\ \hline
# 155  &  langues vivantes, civilisations étrangères et régionales  &  8.9 \\ \hline
# 156  &  assistance médico-technique  &  8.9 \\ \hline
# 157  &  conseil en information médicale  &  8.6 \\ \hline
# 158  &  biochimie des produits alimentaires  &  8.1 \\ \hline
# 159  &  psychologie  &  6.7 \\ \hline
# 160  &  fabrication textile  &  6.0 \\ \hline
# 161  &  littérature appliquée à la documentation, communication, lettres et enseignement  &  4.9 \\ \hline
# 162  &  art dramatique  &  3.9 \\ \hline
# 163  &  français, littérature et civilisation française  &  3.8 \\ \hline
# 164  &  direction des centres de loisirs ou culturels  &  3.7 \\ \hline
# 165  &  costume et habillage spectacle  &  2.3 \\ \hline
# 166  &  intervention socioéducative  &  1.5 \\ \hline
# 167  &  animation de loisirs auprès d'enfants ou d'adolescents  &  1.5 \\ \hline
# 168  &  accueil touristique  &  0.7 \\ \hline
# 169  &  arts du cirque et arts visuels  &  0.7 \\ \hline

# %%
for i,el in enumerate(all_fem_gap):
    print(i+1, " & ", el[0], " & ", round(el[1],2), "\\\ \hline")
# Out:
# 1  &  soins infirmiers spécialisés en puériculture  &  -32.9 \\ \hline
# 2  &  mannequinat et pose artistique  &  -24.2 \\ \hline
# 3  &  aide en puériculture  &  -22.7 \\ \hline
# 4  &  coiffure  &  -21.3 \\ \hline
# 5  &  secrétariat et assistanat médical ou médico-social  &  -21.1 \\ \hline
# 6  &  dentellerie, broderie  &  -20.5 \\ \hline
# 7  &  secrétariat comptable  &  -18.7 \\ \hline
# 8  &  danse  &  -18.5 \\ \hline
# 9  &  accompagnement et médiation familiale  &  -16.2 \\ \hline
# 10  &  diététique  &  -16.0 \\ \hline
# 11  &  retouches en habillement  &  -14.2 \\ \hline
# 12  &  soins infirmiers généralistes  &  -13.9 \\ \hline
# 13  &  coiffure, esthétique et autres spécialites de services aux personnes  &  -13.3 \\ \hline
# 14  &  esthétique  &  -12.4 \\ \hline
# 15  &  stylisme  &  -10.5 \\ \hline
# 16  &  travail social  &  -9.7 \\ \hline
# 17  &  soins infirmiers spécialisés en anesthésie  &  -9.4 \\ \hline
# 18  &  services domestiques  &  -8.5 \\ \hline
# 19  &  toilettage des animaux  &  -8.4 \\ \hline
# 20  &  création textile  &  -7.4 \\ \hline
# 21  &  maquillage de scène  &  -6.2 \\ \hline
# 22  &  arts plastiques  &  -6.1 \\ \hline
# 23  &  psychologie de la santé  &  -6.1 \\ \hline
# 24  &  pâtisserie,confiserie,chocolaterie et glacerie  &  -6.0 \\ \hline
# 25  &  éducation de jeunes enfants  &  -5.4 \\ \hline
# 26  &  traduction,interprétariat  &  -4.8 \\ \hline
# 27  &  linguistique et didactique des langues  &  -3.8 \\ \hline
# 28  &  orthophonie  &  -3.7 \\ \hline
# 29  &  interprétariat et traduction  &  -2.3 \\ \hline
# 30  &  psychopédagogie  &  -1.5 \\ \hline
# 31  &  sociologie et travail social  &  -1.5 \\ \hline
# 32  &  traduction, interprétariat  &  -1.5 \\ \hline
# 33  &  aide et médiation judiciaire  &  -0.8 \\ \hline

# %%
mean_gap_total = sum([el[1] for el in all_sorted_gap])/len(all_sorted_gap)
mean_gap_total
# Out:
# 21.742857142857147

# %%
import csv

with open("sorted_gap.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(sorted_gap)

# %%
nogap = [el for el in all_sorted_gap if el[1]==0]
nogap
# Out:
# [['sciences sociales', 0.0]]

# %%
"""FIGURE ET TABLEAU POUR CES THÈMES"""

masc_gap = all_masc_gap
fem_gap = all_fem_gap
warnings.filterwarnings('ignore')
topics = [el[0] for el in masc_gap[:5]]+[el[0] for el in fem_gap[:5]]

table = []

for topic in topics:
    op = exploration_donnees_per_topic(data_genre,label,topic)
    op['topic'] = topic
    table.append(op)

print(tabulate(table, headers='keys'))

for d in table:
    if "Ambigu" not in d:
        d["Ambigu"]="0%"
        
table_new = [{"Neutre":float(d["Neutre"][:-1]), "Fem":float(d["Fem"][:-1]),
             "Masc":float(d["Masc"][:-1]),"Ambigu":float(d["Ambigu"][:-1])} for d in table]


# ajouter une barre pour le total
total = {}
for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
    n = sum([dic[genre] for dic in table_new])
    total[genre] = n/len(table_new)
    
#table_new.append(total)
table_new.insert(0,total)

print(table_new)

df = pd.DataFrame(table_new, index=["TOTAL"]+topics)
ax = df.plot(kind="barh", stacked=True)
#ax.set_title("",color='black')
ax.legend(bbox_to_anchor=(1.0, 1.0))
plt.savefig("fig/gender_per_topic_10biased.png",bbox_inches = "tight")
ax.plot()
# Out:
# Masc    Neutre    Fem    Ambigu    topic
# ------  --------  -----  --------  --------------------------------------------------
# 64.4%   31.9%     3.0%   0.7%      mécanique aéronautique et spatiale
# 64.6%   29.9%     4.7%   0.8%      direction de chantier du btp
# 62.8%   30.2%     6.2%   0.8%      conduite d'engins de chantier
# 59.7%   35.3%     4.2%   0.8%      conduite d'engins agricoles et forestiers
# 57.6%   38.1%     2.2%   2.2%      métallurgie
# 13.4%   37.3%     46.3%  3.0%      soins infirmiers spécialisés en puériculture
# 18.8%   33.6%     43.0%  4.7%      mannequinat et pose artistique
# 21.2%   29.5%     43.9%  5.3%      aide en puériculture
# 23.7%   26.0%     45.0%  5.3%      coiffure
# 21.1%   35.2%     42.2%  1.6%      secrétariat et assistanat médical ou médico-social
# [{'Masc': 40.730000000000004, 'Fem': 24.07, 'Neutre': 32.699999999999996, 'Ambigu': 2.5200000000000005}, {'Neutre': 31.9, 'Fem': 3.0, 'Masc': 64.4, 'Ambigu': 0.7}, {'Neutre': 29.9, 'Fem': 4.7, 'Masc': 64.6, 'Ambigu': 0.8}, {'Neutre': 30.2, 'Fem': 6.2, 'Masc': 62.8, 'Ambigu': 0.8}, {'Neutre': 35.3, 'Fem': 4.2, 'Masc': 59.7, 'Ambigu': 0.8}, {'Neutre': 38.1, 'Fem': 2.2, 'Masc': 57.6, 'Ambigu': 2.2}, {'Neutre': 37.3, 'Fem': 46.3, 'Masc': 13.4, 'Ambigu': 3.0}, {'Neutre': 33.6, 'Fem': 43.0, 'Masc': 18.8, 'Ambigu': 4.7}, {'Neutre': 29.5, 'Fem': 43.9, 'Masc': 21.2, 'Ambigu': 5.3}, {'Neutre': 26.0, 'Fem': 45.0, 'Masc': 23.7, 'Ambigu': 5.3}, {'Neutre': 35.2, 'Fem': 42.2, 'Masc': 21.1, 'Ambigu': 1.6}]
# []

# %%
means = {"total":mean_gap_total}
for model in modeles:
    sorted_gap, masc_gap, fem_gap = biased_topics(all_topics,data_genre[data_genre["model"] == model])
    mean_gap = sum([el[1] for el in sorted_gap])/len(sorted_gap)
    #print(model, mean_gap)
    means[model]=mean_gap
    
means
# Out:
# {'total': 21.742857142857147,
#  'bloom-560m': 15.921674876847293,
#  'bloom-3b': 18.482266009852218,
#  'bloom-7b': 10.98916256157637,
#  'vigogne-2-7b': 68.96157635467986,
#  'gpt2-fr': 12.811822660098532,
#  'xglm-2': 0.3640394088669988}

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(list(means.keys()), list(means.values()))
ax.tick_params(labelrotation=90) 
ax.set_ylabel("Moyenne d'Écart Genré par thème")
#ax.set_title('Problèmes de qualité de données')
i = 0
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2,
             y+height*1.01,
             round(list(means.values())[i],2),
             ha='center',
             weight='bold')
    i+=1
    
plt.savefig("fig/moy_gap_topic_model.png")

# %% [markdown]
# ## Croisement proportions genre par modèle ET par domaine professionnel

# %%
import warnings
def exploration_donnees_per_topic_model(dataset, golden_gender,model, topic ,savecsv=False, savefig = False):
    
    dataset = dataset[dataset["Theme"] == topic]
    dataset = dataset[dataset["model"] == model]
    x_fig = dataset[golden_gender].value_counts(normalize=True)
    x=dataset[golden_gender].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
    titre = f"Nombre d'instances par étiquette pour {model}, {topic}\n"
    
    if savecsv:
        x.to_csv(f"value_counts_{label}_{model}_{topic}.csv")
        
    return x.to_dict()

warnings.filterwarnings('ignore')

all_topics = list(set(data_genre["Theme"]))
topic_mod = {}

"""Ordre par modèle, puis par topic"""
for model in modeles:
    table = []
    sorted_gap, masc_gap, fem_gap = biased_topics(all_topics,data_genre[data_genre["model"] == model])
    topics = [el[0] for el in masc_gap[:5]]+[el[0] for el in fem_gap[:5]]
    topic_mod[model]=topics
    for topic in topics:
        op = exploration_donnees_per_topic_model(data_genre,label,model,topic)
        op['topic'] = topic
        table.append(op)

    print("\n",model)
    print(tabulate(table, headers='keys'))
    
    for d in table:
        for genre in ["Neutre","Fem", "Masc","Ambigu"]:
            if genre not in d:
                d[genre]="0%"
    table_new = [{"Neutre":float(d["Neutre"][:-1]), "Fem":float(d["Fem"][:-1]),
                 "Masc":float(d["Masc"][:-1]),"Ambigu":float(d["Ambigu"][:-1])} for d in table]
    # ajouter une barre pour le total
    total = {}
    for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
        n = sum([dic[genre] for dic in table_new])
        total[genre] = n/len(table_new)

    #table_new.append(total)
    table_new.insert(0,total)

    label_topics = ["secrétariat et assistanat médical" if "secrétariat et assistanat médical ou médico-social" in item else item for item in topics]
    label_topics = ["langues étrangères appliquées" if "langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation" in item else item for item in label_topics]
    label_topics = ["installation et maintenance en froid" if "conditionnement d'air" in item else item for item in label_topics]
    label_topics = ["coiffure, esthétique, services" if "autres spécialites de services" in item else item for item in label_topics]
    label_topics = ["prod. et exploit. de systèmes d'info." if "systèmes d'information" in item else item for item in label_topics]
    label_topics = ["qualité et protection santé du btp" if "protection santé du btp" in item else item for item in label_topics]
    label_topics = ["gestion de portefeuilles" if "portefeuilles" in item else item for item in label_topics]
    label_topics = ["soins infirmiers (puériculture)" if "spécialisés en puériculture" in item else item for item in label_topics]
    label_topics = ["soins infirmiers (anesthésie)" if "spécialisés en anesthésie" in item else item for item in label_topics]

        
    df = pd.DataFrame(table_new, index=["TOTAL"]+label_topics)
    ax = df.plot(kind="barh", stacked=True)
    ax.set_title(model,color='black')
    ax.legend(bbox_to_anchor=(1.0, 1.0))
    plt.savefig(f"fig/auto_gender_per_model+topic_{model}.png",bbox_inches = "tight")
    ax.plot()
# Out:
#  bloom-560m
# Masc    Neutre    Fem    topic                                                                                                   Ambigu
# ------  --------  -----  ------------------------------------------------------------------------------------------------------  --------
# 57.9%   36.8%     5.3%   mécanique aéronautique et spatiale
# 57.1%   28.6%     4.8%   langues étrangères appliquées au tourisme, au commerce international, aux affaires, à la documentation  9.5%
# 57.1%   33.3%     4.8%   conduite de grue                                                                                        4.8%
# 58.3%   29.2%     8.3%   sciences de la terre                                                                                    4.2%
# 54.5%   40.9%     4.5%   aménagement paysager
# 5.3%    52.6%     36.8%  stylisme                                                                                                5.3%
# 19.0%   33.3%     47.6%  costume et habillage spectacle
# 4.8%    61.9%     28.6%  photographie                                                                                            4.8%
# 25.0%   30.0%     45.0%  gestion en banque et assurance
# 19.0%   42.9%     38.1%  travail social
#
#  bloom-3b
# Masc    Neutre    topic                                                        Fem    Ambigu
# ------  --------  -----------------------------------------------------------  -----  --------
# 82.6%   17.4%     mécanique générale et de précision
# 82.6%   17.4%     installation et maintenance en froid, conditionnement d'air
# 82.6%   13.0%     machinerie spectacle                                         4.3%
# 82.6%   13.0%     electricité électronique                                     4.3%
# 81.8%   13.6%     direction de chantier du btp                                 4.5%
# 10.0%   10.0%     soins infirmiers spécialisés en puériculture                 80.0%
# 14.3%   9.5%      aide en puériculture                                         76.2%
# 16.7%   8.3%      coiffure                                                     75.0%
# 15.0%   15.0%     secrétariat et assistanat médical ou médico-social           70.0%
# 8.7%    21.7%     diététique                                                   60.9%  8.7%
#
#  bloom-7b
# Masc    Neutre    topic                                                                 Fem    Ambigu
# ------  --------  --------------------------------------------------------------------  -----  --------
# 87.0%   13.0%     maçonnerie
# 83.3%   16.7%     métallurgie
# 83.3%   11.1%     personnel de la défense                                               5.6%
# 81.8%   13.6%     mécanique aéronautique et spatiale                                    4.5%
# 75.0%   18.8%     direction de chantier du btp                                                 6.2%
#         31.6%     diététique                                                            63.2%  5.3%
# 5.3%    21.1%     secrétariat et assistanat médical ou médico-social                    68.4%  5.3%
# 4.3%    26.1%     coiffure, esthétique et autres spécialites de services aux personnes  65.2%  4.3%
# 14.3%   14.3%     psychologie de la santé                                               71.4%
# 4.8%    28.6%     sociologie et travail social                                          61.9%  4.8%
#
#  vigogne-2-7b
# Masc    Neutre    topic                                                      Fem    Ambigu
# ------  --------  ---------------------------------------------------------  -----  --------
# 91.7%   8.3%      construction de décors de spectacle
# 91.7%   8.3%      boulangerie - viennoiserie
# 91.3%   8.7%      gestion de portefeuilles sur les marchés financiers
# 91.3%   8.7%      direction de chantier du btp
# 90.9%   9.1%      qualité sécurité environnement et protection santé du btp
# 27.3%   18.2%     secrétariat comptable                                      50.0%  4.5%
#
#  gpt2-fr
# Masc    Ambigu    Neutre    topic                                         Fem
# ------  --------  --------  --------------------------------------------  -----
# 83.3%   8.3%      8.3%      prise de son et sonorisation
# 79.2%             20.8%     conduite d'engins de chantier
# 83.3%             12.5%     informatique, traitement de l'information     4.2%
# 62.5%             37.5%     mécanique aéronautique et spatiale
# 58.3%             41.7%     information météorologique
# 12.5%             20.8%     soins infirmiers généralistes                 66.7%
# 13.0%   4.3%      17.4%     coiffure                                      65.2%
# 20.8%   8.3%      4.2%      création textile                              66.7%
# 8.3%    4.2%      33.3%     dentellerie, broderie                         54.2%
# 8.3%    4.2%      33.3%     soins infirmiers spécialisés en puériculture  54.2%
#
#  xglm-2
# Neutre    Masc    Fem    topic                                                 Ambigu
# --------  ------  -----  ----------------------------------------------------  --------
# 47.8%     47.8%   4.3%   architecture du btp et du paysage
# 58.8%     41.2%          géographie
# 59.1%     40.9%          réalisation et montage en tuyauterie
# 60.0%     40.0%          mécanique générale et de précision
# 61.9%     38.1%          production et exploitation de systèmes d'information
# 43.5%     4.3%    52.2%  accompagnement et médiation familiale
# 52.2%             47.8%  danse
# 54.5%             45.5%  interprétariat et traduction
# 34.8%     8.7%    52.2%  soins infirmiers spécialisés en anesthésie            4.3%
# 59.1%             40.9%  aide en puériculture

# %%
"""Ordre par topic, puis par modèle"""
#modeles = ["bloom-560m", "bloom-3b", "bloom-7b", "vigogne-2-7b", "gpt2-fr", "xglm-2.9B"]
for topic in topics:
    table = []
    for model in modeles:
        op = exploration_donnees_per_topic_model(data_genre,label,model,topic)
        op['model'] = model
        table.append(op)

    print("\n",topic)
    print(tabulate(table, headers='keys'))
    
    for d in table:
        for genre in ["Neutre","Fem", "Masc","Ambigu"]:
            if genre not in d:
                d[genre]="0%"
    table_new = [{"Neutre":float(d["Neutre"][:-1]), "Fem":float(d["Fem"][:-1]),
                 "Masc":float(d["Masc"][:-1]),"Ambigu":float(d["Ambigu"][:-1])} for d in table]
    new_dic = {}
    for genre in ["Neutre", "Fem", "Masc", "Ambigu"]:
        new_dic[genre] = sum([d[genre] for d in table_new])/len(table_new)
    #table_new.append(new_dic)
    table_new.insert(0,new_dic)
    
    """    # ajouter une barre pour le total
    total = {}
    for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
        n = sum([dic[genre] for dic in table_new])
        total[genre] = n/len(table_new)

    table_new.append(total)"""

    df = pd.DataFrame(table_new, index=["TOTAL"]+modeles)
    ax = df.plot(kind="barh", stacked=True)
    ax.set_title(topic,color='black')
    ax.legend(bbox_to_anchor=(1.0, 1.0))
    plt.savefig(f"analyse_fig-tables/gender_per_topic+model_{topic}.png",bbox_inches = "tight")
    ax.plot()
# Out:
#  architecture du btp et du paysage
# Neutre    Masc    Ambigu    Fem    model
# --------  ------  --------  -----  ------------
# 62.5%     20.8%   8.3%      8.3%   bloom-560m
# 18.2%     59.1%             22.7%  bloom-3b
# 37.5%     50.0%             12.5%  bloom-7b
# 34.8%     65.2%                    vigogne-2-7b
# 26.1%     52.2%   4.3%      17.4%  gpt2-fr
# 47.8%     47.8%             4.3%   xglm-2
#
#  géographie
# Neutre    Masc    Fem    Ambigu    model
# --------  ------  -----  --------  ------------
# 52.2%     26.1%   17.4%  4.3%      bloom-560m
# 20.8%     50.0%   25.0%  4.2%      bloom-3b
# 40.9%     31.8%   22.7%  4.5%      bloom-7b
# 26.1%     65.2%   8.7%             vigogne-2-7b
# 33.3%     41.7%   25.0%            gpt2-fr
# 58.8%     41.2%                    xglm-2
#
#  réalisation et montage en tuyauterie
# Masc    Neutre    Fem    model         Ambigu
# ------  --------  -----  ------------  --------
# 45.5%   40.9%     13.6%  bloom-560m
# 59.1%   31.8%     4.5%   bloom-3b      4.5%
# 54.5%   36.4%     9.1%   bloom-7b
# 81.8%   18.2%            vigogne-2-7b
# 41.7%   41.7%     12.5%  gpt2-fr       4.2%
# 40.9%   59.1%            xglm-2
#
#  mécanique générale et de précision
# Masc    Neutre    Fem    Ambigu    model
# ------  --------  -----  --------  ------------
# 31.8%   31.8%     22.7%  13.6%     bloom-560m
# 82.6%   17.4%                      bloom-3b
# 66.7%   28.6%     4.8%             bloom-7b
# 77.3%   22.7%                      vigogne-2-7b
# 54.2%   33.3%     12.5%            gpt2-fr
# 40.0%   60.0%                      xglm-2
#
#  production et exploitation de systèmes d'information
# Neutre    Masc    Fem    model         Ambigu
# --------  ------  -----  ------------  --------
# 34.8%     34.8%   30.4%  bloom-560m
# 27.3%     63.6%   4.5%   bloom-3b      4.5%
# 55.0%     45.0%          bloom-7b
# 12.5%     83.3%          vigogne-2-7b  4.2%
# 37.5%     50.0%   12.5%  gpt2-fr
# 61.9%     38.1%          xglm-2
#
#  accompagnement et médiation familiale
# Masc    Neutre    Fem    model         Ambigu
# ------  --------  -----  ------------  --------
# 47.6%   28.6%     23.8%  bloom-560m
# 21.7%   30.4%     47.8%  bloom-3b
# 9.1%    45.5%     45.5%  bloom-7b
# 52.2%   17.4%     26.1%  vigogne-2-7b  4.3%
# 20.8%   25.0%     54.2%  gpt2-fr
# 4.3%    43.5%     52.2%  xglm-2
#
#  danse
# Neutre    Fem    Masc    Ambigu    model
# --------  -----  ------  --------  ------------
# 33.3%     33.3%  23.8%   9.5%      bloom-560m
# 22.7%     50.0%  27.3%             bloom-3b
# 47.6%     38.1%  14.3%             bloom-7b
# 29.2%     20.8%  45.8%   4.2%      vigogne-2-7b
# 33.3%     50.0%  16.7%             gpt2-fr
# 52.2%     47.8%                    xglm-2
#
#  interprétariat et traduction
# Masc    Neutre    Ambigu    Fem    model
# ------  --------  --------  -----  ------------
# 39.1%   34.8%     13.0%     13.0%  bloom-560m
# 21.7%   26.1%     8.7%      43.5%  bloom-3b
# 13.3%   60.0%               26.7%  bloom-7b
# 56.5%   30.4%     4.3%      8.7%   vigogne-2-7b
# 30.4%   17.4%     8.7%      43.5%  gpt2-fr
#         54.5%               45.5%  xglm-2
#
#  soins infirmiers spécialisés en anesthésie
# Masc    Neutre    Fem    Ambigu    model
# ------  --------  -----  --------  ------------
# 33.3%   33.3%     29.2%  4.2%      bloom-560m
# 28.6%   9.5%      52.4%  9.5%      bloom-3b
# 18.2%   31.8%     40.9%  9.1%      bloom-7b
# 54.2%   16.7%     12.5%  16.7%     vigogne-2-7b
# 16.7%   50.0%     33.3%            gpt2-fr
# 8.7%    34.8%     52.2%  4.3%      xglm-2
#
#  aide en puériculture
# Neutre    Masc    Fem    Ambigu    model
# --------  ------  -----  --------  ------------
# 52.4%     23.8%   14.3%  9.5%      bloom-560m
# 9.5%      14.3%   76.2%            bloom-3b
# 38.1%     4.8%    52.4%  4.8%      bloom-7b
# 4.3%      60.9%   21.7%  13.0%     vigogne-2-7b
# 16.7%     20.8%   58.3%  4.2%      gpt2-fr
# 59.1%             40.9%            xglm-2

# %% [markdown]
# ## Stylométrie (stats sur les textes)
#
# Quelques statistiques & graphiques sur les données : moyenne de nombre de mots, de caractères, de mots uniques
# (fonction adaptée de code trouvé en ligne : https://medium.com/analytics-vidhya/nlp-tutorial-for-text-classification-in-python-8f19cd17b49e )

# %%
def stats_donnees(dataset, label, filtre_model=None):
    cat_m="Masc"
    cat_f="Fem"
    cat_n="Neutre"
    cat_a = "Ambigu"
    
    if filtre_model:
        dataset = dataset[dataset["model"]==filtre_model]
    
    #1. WORD-COUNT
    dataset['word_count'] = dataset["output"].apply(lambda x: len(str(x).split()))
    
    #2. CHARACTER-COUNT
    dataset['char_count'] = dataset['output'].apply(lambda x: len(str(x)))

    #3. UNIQUE WORD-COUNT
    dataset['unique_word_count'] = dataset['output'].apply(lambda x: len(set(str(x).split())))
    
    res_word= {"Masc": dataset[dataset[label]==cat_m]['word_count'].mean(), "Fem": dataset[dataset[label]==cat_f]['word_count'].mean(),
          "Neutre":dataset[dataset[label]==cat_n]['word_count'].mean(), "Ambigu":dataset[dataset[label]==cat_a]['word_count'].mean(),
              }
    
    res_char= {"Masc": dataset[dataset[label]==cat_m]['char_count'].mean(), "Fem": dataset[dataset[label]==cat_f]['char_count'].mean(),
          "Neutre":dataset[dataset[label]==cat_n]['char_count'].mean(), "Ambigu":dataset[dataset[label]==cat_a]['char_count'].mean()}

    res_uniqueword= {"Masc": dataset[dataset[label]==cat_m]['unique_word_count'].mean(), "Fem": dataset[dataset[label]==cat_f]['unique_word_count'].mean(),
          "Neutre":dataset[dataset[label]==cat_n]['unique_word_count'].mean(), "Ambigu":dataset[dataset[label]==cat_a]['unique_word_count'].mean()}

    
    return res_char, res_word, res_uniqueword


table = []
print("Char")
for model in modeles:
    op = stats_donnees(data_genre,label,model)[0]
    op = {k: v for k, v in op.items() if pd.Series(v).notna().all()}
    op['total'] = sum(op.values())/len(op)
    op['model'] = model
    table.append(op)
print(tabulate(table, headers='keys'))
    
table = []
print("\nWord")
for model in modeles:
    op = stats_donnees(data_genre,label,model)[1]
    op = {k: v for k, v in op.items() if pd.Series(v).notna().all()}
    op['total'] = sum(op.values())/len(op)
    op['model'] = model
    table.append(op)
print(tabulate(table, headers='keys'))
    
table = []
print("\nUnique word")
for model in modeles:
    op = stats_donnees(data_genre,label,model)[2]
    op = {k: v for k, v in op.items() if pd.Series(v).notna().all()}
    op['total'] = sum(op.values())/len(op)
    op['model'] = model
    table.append(op)

print(tabulate(table, headers='keys'))

"""for model in modeles:
    print("\n ---", model)
    stats_donnees(data_genre, label, model)
    print("*"*60)"""
# Out:
# Char
#     Masc       Fem    Neutre    Ambigu     total  model
# --------  --------  --------  --------  --------  ------------
#  632.054   630.37    586.259   653.982   625.666  bloom-560m
# 1033.31   1020.11    781.268  1066.88    975.389  bloom-3b
# 1068.36   1068.03    888.993  1106.07   1032.86   bloom-7b
#  725.549   659.659   634.153   774.092   698.363  vigogne-2-7b
# 1053.15   1042.97   1036.9    1041.17   1043.55   gpt2-fr
#  384.024   390.374   294.846   415.054   371.074  xglm-2
#
# Word
#     Masc       Fem    Neutre    Ambigu     total  model
# --------  --------  --------  --------  --------  ------------
# 105.698   105.58     97.4029  109.158   104.46    bloom-560m
# 168.778   167.551   127.502   175.667   159.874   bloom-3b
# 172.525   173.546   143.498   178.869   167.109   bloom-7b
# 117.387   107.039   101.477   124.316   112.555   vigogne-2-7b
# 170.113   169.38    166.466   168.123   168.52    gpt2-fr
#  63.2251   63.4505   48.7716   67.8378   60.8213  xglm-2
#
# Unique word
#    Masc       Fem    Neutre    Ambigu    total  model
# -------  --------  --------  --------  -------  ------------
# 68.6776   68.4273   64.8254   71.3099  68.3101  bloom-560m
# 95.7829   96.5777   77.344   102.085   92.9473  bloom-3b
# 98.0052  100.959    83.2147  103.051   96.3075  bloom-7b
# 74.3019   69.3578   67.342    79.3265  72.5821  vigogne-2-7b
# 97.1935   97.4844   89.2692   99.3699  95.8292  gpt2-fr
# 46.0474   46.427    37.7265   48.9459  44.7867  xglm-2
# 'for model in modeles:\n    print("\n ---", model)\n    stats_donnees(data_genre, label, model)\n    print("*"*60)'

# %%
"""PRÉPARER FICHIERS TXT POUR TXM"""
for genre in ["Masc", "Fem", "Neutre", "Ambigu"]:
    df_genre = data_genre[data_genre["Identified_gender"]==genre]
    with open(f"txm/global_{genre}.txt", "w") as f:
        f.write(str(list(df_genre["output"])))
